# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, [3, 4]].values

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import SpectralClustering

# %%
clusmodel = SpectralClustering(3, affinity='precomputed', n_init=100, assign_labels='discretize') 
label = clusmodel.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6568\1433199192.py in <module>
#       1 clusmodel = SpectralClustering(3, affinity='precomputed', n_init=100, assign_labels='discretize')
# ----> 2 label = clusmodel.fit_predict(X)
#
# ~\anaconda3\envs\aiml\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     445         # non-optimized default implementation; override when a better
#     446         # method is possible for a given clustering algorithm
# --> 447         self.fit(X)
#     448         return self.labels_
#     449
#
# ~\anaconda3\envs\aiml\lib\site-packages\sklearn\cluster\spectral.py in fit(self, X, y)
#     491                                            n_init=self.n_init,
#     492                                            eigen_tol=self.eigen_tol,
# --> 493                                            assign_labels=self.assign_labels)
#     494         return self
#     495
#
# ~\anaconda3\envs\aiml\lib\site-packages\sklearn\cluster\spectral.py in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels)
#     262                               eigen_solver=eigen_solver,
#     263                               random_state=random_state,
# --> 264                               eigen_tol=eigen_tol, drop_first=False)
#     265
#     266     if assign_labels == 'kmeans':
#
# ~\anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\spectral_embedding_.py in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     209       https://doi.org/10.1137%2FS1064827500366124
#     210     """
# --> 211     adjacency = check_symmetric(adjacency)
#     212
#     213     try:
#
# ~\anaconda3\envs\aiml\lib\site-packages\sklearn\utils\validation.py in check_symmetric(array, tol, raise_warning, raise_exception)
#     838     if (array.ndim != 2) or (array.shape[0] != array.shape[1]):
#     839         raise ValueError("array must be 2-dimensional and square. "
# --> 840                          "shape = {0}".format(array.shape))
#     841
#     842     if sp.issparse(array):
#
# ValueError: array must be 2-dimensional and square. shape = (200, 2)

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=label

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0               -1
# 1                3
# 2                0
# 3                3
# 4               -1
# ..             ...
# 195             -1
# 196             -1
# 197             -1
# 198             -1
# 199             -1
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\prasanth.s\anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
